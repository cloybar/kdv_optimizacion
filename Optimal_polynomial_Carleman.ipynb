# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy.optimize import minimize

# %%
def objective(x):
    a=x[0]
    b=x[1]
    c=x[2]
    return 2*b+c-2*a
def constraint1(x):
    a=x[0]
    b=x[1]
    c=x[2]
    return 14*a*(b-2*a)**4-1.5*(b**2)*(A**2)-1.5*(b+c-a)*a*b*(A**2)-1.5*a*(b**2)*B*C-0.75*(b+c-a)*(A**4)-0.125*b*(A**2)*B*C
def constraint2(x):
    a=x[0]
    b=x[1]
    c=x[2]
    return 6*a*(b-2*a)**2-1.5*b*(A**2)-0.75*a*B*C
def constraint3(x):
    a=x[0]
    b=x[1]
    c=x[2]
    return 4*a*(b-2*a)**3-0.25*(b+c-a)*(A**2)-2*(b-2*a)*B*C
def constraint4(x):
    return x[1]-2*x[0]

x0=[1, 3, 1]
print(objective(x0))

b=(0.1, None)
bnds=(b, b, b)
con1={'type':'ineq', 'fun': constraint1}
con2={'type':'ineq', 'fun': constraint2}
con3={'type':'ineq', 'fun': constraint3}
con4={'type':'ineq', 'fun': constraint4}
cons=[con1, con2, con3, con4]
# Out:
# 5

# %%
C=0.1
lista=[1, 2, 3, 4]
for A in lista:
    for B in lista:
        sol=minimize(objective, x0, method='SLSQP', bounds=bnds, constraints=cons)
        print(A, B)
        print(sol)
# Out:
# 1 1
#      fun: 3.096362415291551
#      jac: array([-2.,  2.,  1.])
#  message: 'Optimization terminated successfully.'
#     nfev: 36
#      nit: 7
#     njev: 7
#   status: 0
#  success: True
#        x: array([0.37440927, 1.87259048, 0.1       ])
# 1 2
#      fun: 3.1132224525167533
#      jac: array([-2.,  2.,  1.])
#  message: 'Optimization terminated successfully.'
#     nfev: 36
#      nit: 7
#     njev: 7
#   status: 0
#  success: True
#        x: array([0.37236642, 1.87897764, 0.1       ])
# 1 3
#      fun: 3.129890758922712
#      jac: array([-2.,  2.,  1.])
#  message: 'Optimization terminated successfully.'
#     nfev: 36
#      nit: 7
#     njev: 7
#   status: 0
#  success: True
#        x: array([0.37044737, 1.88539275, 0.1       ])
# 1 4
#      fun: 3.146372392360461
#      jac: array([-2.,  2.,  1.])
#  message: 'Optimization terminated successfully.'
#     nfev: 36
#      nit: 7
#     njev: 7
#   status: 0
#  success: True
#        x: array([0.36864001, 1.89182621, 0.1       ])
# 2 1
#      fun: 0.2999999890390488
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 99
#      nit: 17
#     njev: 13
#   status: 8
#  success: False
#        x: array([0.1       , 0.19999999, 0.1       ])
# 2 2
#      fun: 0.2999999997281205
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 82
#      nit: 14
#     njev: 10
#   status: 8
#  success: False
#        x: array([0.1, 0.2, 0.1])
# 2 3
#      fun: 0.2995989550490961
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 35
#      nit: 11
#     njev: 7
#   status: 8
#  success: False
#        x: array([0.1       , 0.19979948, 0.1       ])
# 2 4
#      fun: 0.29833731391626056
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 200
#      nit: 22
#     njev: 18
#   status: 8
#  success: False
#        x: array([0.1       , 0.19916866, 0.1       ])
# 3 1
#      fun: 0.2159485150974923
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 96
#      nit: 14
#     njev: 10
#   status: 8
#  success: False
#        x: array([0.1       , 0.15797426, 0.1       ])
# 3 2
#      fun: 0.0981249299701196
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 30
#      nit: 10
#     njev: 6
#   status: 8
#  success: False
#        x: array([0.10093754, 0.1       , 0.1       ])
# 3 3
#      fun: 0.2999999989257185
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 131
#      nit: 18
#     njev: 14
#   status: 8
#  success: False
#        x: array([0.1, 0.2, 0.1])
# 3 4
#      fun: 0.23310779817221866
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 30
#      nit: 10
#     njev: 6
#   status: 8
#  success: False
#        x: array([0.1      , 0.1665539, 0.1      ])
# 4 1
#      fun: 0.10000000000000003
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 25
#      nit: 9
#     njev: 5
#   status: 8
#  success: False
#        x: array([0.1, 0.1, 0.1])
# 4 2
#      fun: 0.2999994117082861
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 165
#      nit: 23
#     njev: 19
#   status: 8
#  success: False
#        x: array([0.1       , 0.19999971, 0.1       ])
# 4 3
#      fun: 0.2999996312975202
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 260
#      nit: 24
#     njev: 20
#   status: 8
#  success: False
#        x: array([0.1       , 0.19999982, 0.1       ])
# 4 4
#      fun: 0.2642555485627841
#      jac: array([-2.,  2.,  1.])
#  message: 'Positive directional derivative for linesearch'
#     nfev: 40
#      nit: 10
#     njev: 6
#   status: 8
#  success: False
#        x: array([0.1       , 0.18212777, 0.1       ])
